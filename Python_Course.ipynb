# %% [markdown]
# # AI Python for beginners course

# %% [markdown]
# ### Generative AI systems are AI models that can create new content instead of only analyzing or classifying existing data.
# * OpenAI’s ChatGPT
# * Anthropic’s Claude
# * Google’s Gemini

# %% [markdown]
# ### Never to code alone as you will have an experienced buddy next to you

# %% [markdown]
# # Programming is giving precise instructions to computer to perform a task

# %% [markdown]
# # Before if any doubt, need to check with professor , now if you have any doubt you can ask chatgpt
#
# * type prompt and you will get response
# * ask chatgpt to generate code for you and modify it as per your requirement
# * give me code to write Hello world
# * Say hello to me.. not to world
# * write a code to find out number of days from 22nd may to august 21
#
# ## AI is transforming the way code is written

# %% [markdown]
# ### Running your first program

# %%
print("Hello World !")
# Out:
# Hello World !

# %% [markdown]
# ### use chatbot to modify your code
# Type in this prompt (substituting your name for mine)
#
#      Modify the code below to have it say hello to me.
#
#      print("Hello, World!")
#
#      My name is Andrew

# %%
print("hello, Leka Lakshmi Dakshinamurthy")
# Out:
# hello, Leka Lakshmi Dakshinamurthy

# %% [markdown]
# # Comments are used to help others to undertand what code does

# %%
# THIS IS A COMMENT - PYTHON WILL IGNORE THIS LINE

# %%
# This is an example of code with multiple
# comments, including this one which
# spans multiple lines
print("Hello, Andrew!")
# Follow up with an additional print command
print("How is your day going?")
# Out:
# Hello, Andrew!
# How is your day going?

# %% [markdown]
# ### Making mistakes is no big deal
#
# * ask chatbot how to fix the code
# * ask chatbot to explain the error message

# %% [markdown]
# ### tips for becoming successful programmer
# * Code daily
# * ask questions to chatbot
# * ask why and how questions
# * instead of copying code, try to understand it

# %% [markdown]
# # Data in python
# * Data : popluation in a place, weekly weather, stock prices
# * Computer can process data such as text, number, spreadsheet, picture(pixel values ) and sound(variation of air pressure)
# * String : double quotes, can be anything in that quotes

# %%
print("hello World")
print("i love to drink tea with my father")
print("¯\_(ツ)_/¯")
print("2.98")
# Out:
# hello World
# i love to drink tea with my father
# ¯\_(ツ)_/¯
# 2.98
# <>:3: SyntaxWarning: invalid escape sequence '\_'
# <>:3: SyntaxWarning: invalid escape sequence '\_'
# C:\Users\lekal\AppData\Local\Temp\ipykernel_23452\3097903231.py:3: SyntaxWarning: invalid escape sequence '\_'
#   print("¯\_(ツ)_/¯")

# %% [markdown]
# # Multi line string
# * use triple quotes
# * print the space that you are mentioning in your code

# %%
print(""" Hello world
                  It is great to be here""")
# Out:
#  Hello world
#                   It is great to be here

# %% [markdown]
# # Check data type in python

# %%
type("Hello World")
# Out:
# str

# %%
type(""" Hello world
                  It is great to be here""")
# Out:
# str

# %%
type("343.4")
# Out:
# str

# %%
type(1000)
# Out:
# int

# %%
type(34.5)
# Out:
# float

# %% [markdown]
# # integer with no decimal part and floats have decimal parts

# %% [markdown]
# ### Use python as calculator

# %%
print(2+5)
print(34-56)
print(34*4)
print(34/5)
print(1.05**10)
# Out:
# 7
# -22
# 136
# 6.8
# 1.628894626777442

# %% [markdown]
# # order of operations
# * PEMDAS
# * Use brackets to mention the order

# %% [markdown]
# # Displaying text and calculation together using formatted sting
#
# * f string(formated string)
# * give f and {}
# * to change the decimal points use :.0f | .1f  | .2f
#
# ## Don't need to remember syntax, use chatbot when you want to modify your code

# %%
print(f"The temperature in 75 F in celcius is {((75 - 32) * 5 / 9)}")
# Out:
# The temperature in 75 F in celcius is 23.88888888888889

# %%
print(f"The temperature in 75 F in celcius is {((75 - 32) * 5 / 9):.0f}")
# Out:
# The temperature in 75 F in celcius is 24

# %%
print(f"The temperature in 75 F in celcius is {((75 - 32) * 5 / 9):.1f}")
# Out:
# The temperature in 75 F in celcius is 23.9

# %%
print(f"The temperature in 75 F in celcius is {((75 - 32) * 5 / 9):.5f}")
# Out:
# The temperature in 75 F in celcius is 23.88889

# %% [markdown]
# ### Mutli line string

# %%
print(f"""

My age is {30+1}
        and my sister age is {30+1+10}""")
# Out:
# My age is 31
#         and my sister age is 41

# %% [markdown]
# # Variables
# * imagine empty box with name as age and stored value as 28
# * Can store text, number
# * variable name should not have space
# * check with chatbot if you have any doubt

# %%
age=28
print(age)
age=5
print(age)
# Out:
# 28
# 5

# %%
name="Leka"
age=31.6
print(f"Youre name is {name} and your age is {age}")
# Out:
# Youre name is Leka and your age is 31.6

# %% [markdown]
# # Functions
# * print, type,len, round
# * takes input and return output
# * function name(arguments)
# * returns value which we can store in a variable

# %%
length=len("Leka Lakshmi Dakshinamurthy")
print(length)
# Out:
# 27

# %% [markdown]
# # Computers are good at
# * repeating same task
# * with high accuracy
# * with high speed

# %% [markdown]
# # List
# * Variables hold one value but list can hold multiple values
# * [  ]
# * can add/delete/retrive/edit list elements
# * index starts with 0

# %%
name="Tommy" # Creating a variables
friends_list=["Sona","Priya","Nishkriya","Sruthy"] # creating list
print(friends_list)
# Out:
# ['Sona', 'Priya', 'Nishkriya', 'Sruthy']

# %%
print(type(friends_list))
# Out:
# <class 'list'>

# %%
print(len(friends_list)) # number of items in list
# Out:
# 4

# %%
# to access one element from list
print(friends_list[0])
print(friends_list[3])
# Out:
# Sona
# Sruthy

# %%
# to add new element
friends_list.append("Suriya")
print(friends_list)
# Out:
# ['Sona', 'Priya', 'Nishkriya', 'Sruthy', 'Suriya']

# %%
# delete element
friends_list.remove("Suriya")
print(friends_list)
# Out:
# ['Sona', 'Priya', 'Nishkriya', 'Sruthy']

# %%
list_of_task=["1. take bath",
              "2. prepare breakfast",
              "3. have medicine",
              "4. Get ready for the day"]

# %% [markdown]
# # For loop

# %%
for items in list_of_task:
    print(items)
# Out:
# 1. take bath
# 2. prepare breakfast
# 3. have medicine
# 4. Get ready for the day

# %%
completed_list=[] # Create empty string
for items in list_of_task:
    completed_list.append(f"Task Completed: {items}")
print(completed_list[3])
# Out:
# Task Completed: 4. Get ready for the day

# %% [markdown]
# # Dictionary
# * if we have long list and it is hard to pull out what item we want
# * using dictionary if we know the key, we can pull the value
# * key value is seperated by :
# * each key value pair is seperated by comma
# * {   }

# %%
ice_cream_flavors = [
    "Vanilla: Classic and creamy with a rich, smooth flavor from real vanilla beans.",
    "Chocolate: Deep and indulgent, made with rich cocoa for a satisfying chocolate experience.",
    "Strawberry: Sweet and fruity, bursting with the fresh taste of ripe strawberries.",
    "Mint Chocolate Chip: Refreshing mint ice cream studded with decadent chocolate chips.",
    "Cookie Dough: Vanilla ice cream loaded with chunks of chocolate chip cookie dough.",
    "Salted Caramel: Sweet and salty with a smooth caramel swirl and a hint of sea salt.",
    "Pistachio: Nutty and creamy, featuring the distinct taste of real pistachios.",
    "Cookies and Cream: Vanilla ice cream packed with chunks of chocolate sandwich cookies.",
    "Mango: Tropical and tangy, made with juicy mangoes for a refreshing treat.",
    "Rocky Road: Chocolate ice cream mixed with marshmallows, nuts, and chocolate chunks."
]

# %%
# Create dictionary
ice_cream_flavors={
    "Vanilla": "Classic and creamy with a rich, smooth flavor from real vanilla beans.",
"Strawberry":"Sweet and fruity, bursting with the fresh taste of ripe strawberries.",
"Mint Chocolate Chip":"Refreshing mint ice cream studded with decadent chocolate chips.",
"Chocolate":" Deep and indulgent, made with rich cocoa for a satisfying chocolate experience."
}

# %%
# to get all keys
print(ice_cream_flavors.keys())
# Out:
# dict_keys(['Vanilla', 'Strawberry', 'Mint Chocolate Chip', 'Chocolate'])

# %%
# to get all value
print(ice_cream_flavors.values())
# Out:
# dict_values(['Classic and creamy with a rich, smooth flavor from real vanilla beans.', 'Sweet and fruity, bursting with the fresh taste of ripe strawberries.', 'Refreshing mint ice cream studded with decadent chocolate chips.', ' Deep and indulgent, made with rich cocoa for a satisfying chocolate experience.'])

# %%
# to access one element from dictionary
print(ice_cream_flavors["Chocolate"])
# Out:
#  Deep and indulgent, made with rich cocoa for a satisfying chocolate experience.

# %%
# to add new item
ice_cream_flavors["Rocky road"]="my favourite ice cream"
print(ice_cream_flavors)
# Out:
# {'Vanilla': 'Classic and creamy with a rich, smooth flavor from real vanilla beans.', 'Strawberry': 'Sweet and fruity, bursting with the fresh taste of ripe strawberries.', 'Mint Chocolate Chip': 'Refreshing mint ice cream studded with decadent chocolate chips.', 'Chocolate': ' Deep and indulgent, made with rich cocoa for a satisfying chocolate experience.', 'Rocky road': 'my favourite ice cream'}

# %%
# to update values
ice_cream_flavors["Rocky road"]="i hate this  ice cream flavor"
print(ice_cream_flavors)
# Out:
# {'Vanilla': 'Classic and creamy with a rich, smooth flavor from real vanilla beans.', 'Strawberry': 'Sweet and fruity, bursting with the fresh taste of ripe strawberries.', 'Mint Chocolate Chip': 'Refreshing mint ice cream studded with decadent chocolate chips.', 'Chocolate': ' Deep and indulgent, made with rich cocoa for a satisfying chocolate experience.', 'Rocky road': 'i hate this  ice cream flavor'}

# %%
# Create dictionary with number, string, list
isabel_facts={
    "age": 25,
    "Favourite color":"Green",
}
#create list as one key value
isabel_facts["Favourite pet"]=["cat","dog","elephant","monkey","horse"]
print(isabel_facts)
# Out:
# {'age': 25, 'Favourite color': 'Green', 'Favourite pet': ['cat', 'dog', 'elephant', 'monkey', 'horse']}

# %% [markdown]
# # List and dictionaries can store multiple values

# %% [markdown]
# * Create a prompt using dictionary and use that prompt as input to the LLM function to get response

# %% [markdown]
# # Boolean datatype
#
# * takes only true and false value
# * output of comparision operator is boolean value(true/false)
# * = is assignment operator
# *  == is to check with value same or not
# * "lek"=="Dask" String comparision is done for password match checking
# * logical operator AND OR

# %%
print(True)
print(False)
print(type(True))
# Out:
# True
# False
# <class 'bool'>

# %%
isable_age=28
daniel_age=30
tommy_age=30

# %%
print(isable_age>daniel_age)
print(isable_age<=daniel_age)

# using variable
age=isable_age>daniel_age
print(age)
type(age)
# Out:
# False
# True
# False
# bool

# %%
print(daniel_age==tommy_age)
print("Leka"=="Lakshmi")
# Out:
# True
# False

# %%
is_tommy_my_friend=True
is_isabel_my_friend=False
print(is_tommy_my_friend and is_isabel_my_friend)
print(is_isabel_my_friend or is_tommy_my_friend)
# Out:
# False
# True

# %% [markdown]
# # Conditional statement

# %%
# Create a list with dictionary
task_list = [
    {
        "description": "Compose a brief email to my boss explaining that I will be late for next week's meeting.",
        "time_to_complete": 3
    },
    {
        "description": "Create an outline for a presentation on the benefits of remote work.",
        "time_to_complete": 60
    },
    {
        "description": "Write a 300-word review of the movie 'The Arrival'.",
        "time_to_complete": 30
    },
    {
        "description": "Create a shopping list for tofu and olive stir fry.",
        "time_to_complete": 5
    }
]

# %%
task=task_list[0]
print(task)
if task["time_to_complete"]<=15:
    print(task["description"])
# Out:
# {'description': "Compose a brief email to my boss explaining that I will be late for next week's meeting.", 'time_to_complete': 3}
# Compose a brief email to my boss explaining that I will be late for next week's meeting.

# %%
for item in task_list:
    if item["time_to_complete"]<=5:
        print(f"\n {item["description"]}")
    else:
        print(f"\nThis task {item["description"]} will take {item["time_to_complete"]} minutes to complete")
# Out:
#  Compose a brief email to my boss explaining that I will be late for next week's meeting.
#
# This task Create an outline for a presentation on the benefits of remote work. will take 60 minutes to complete
#
# This task Write a 300-word review of the movie 'The Arrival'. will take 30 minutes to complete
#
#  Create a shopping list for tofu and olive stir fry.

# %%
fruit_descriptions = {
    "Citrus": [
        { "name": "Orange", "description": "A juicy fruit that is rich in vitamin C, often enjoyed as a snack or in juice form." },
        { "name": "Lemon", "description": "A tart fruit that is commonly used to add flavor to dishes and drinks." }
    ],
    "Berries": [
        { "name": "Strawberry", "description": "A sweet, red fruit that is often used in desserts and smoothies." },
        { "name": "Blueberry", "description": "A small, blue fruit that is packed with antioxidants and often used in baking." }
    ],
    "Tropical": [
        { "name": "Mango", "description": "A sweet and juicy fruit with a unique flavor, often enjoyed fresh or in smoothies." },
        { "name": "Pineapple", "description": "A tropical fruit with a tangy-sweet flavor, great for eating fresh or adding to dishes." }
    ]
}
for fruit in fruit_descriptions["Berries"]:
    if fruit["name"] == "Blueberry":
        print(fruit["description"])
# Out:
# A small, blue fruit that is packed with antioxidants and often used in baking.

# %% [markdown]
# # we can ask chatbot to highlight text from a document that i give and highlight it by bold with differnt color

# %% [markdown]
# ### Using files in python

# %%
from IPython.display import display,Markdown
f=open("email.txt","r") # r for read mode, cannot modify
email=f.read()
f.close() # close free up memory
print(email)
# Out:
# Subject: My Incredible Journey Around the World!
#
# Hi Andrew,
#
# I hope you are doing greatl! I just returned from an incredible trip around the world. I started in New York, enjoying a Broadway show and the skyline. In Rio de Janeiro, I soaked up the sun on Copacabana Beach and hiked to Christ the Redeemer. Cape Town amazed me with its natural beauty and safari adventures. Paris was magical with its charming streets and delicious food. Istanbul's Hagia Sophia and Bosphorus cruise were unforgettable. Tokyo dazzled with its neon lights and delicious sushi. Finally, Sydney's Opera House and Bondi Beach were the perfect end to my journey. Can't wait to share more stories and photos when we catch up!
#
# Best,
#
# Daniel

# %%
email="""
- **Sender:** Daniel
- **Subject:** My Incredible Journey Around the World!
- **Trip Highlights:**
  - New York: Broadway show and skyline
  - Rio de Janeiro: Copacabana Beach and Christ the Redeemer hike
  - Cape Town: Natural beauty and safari adventures
  - Paris: Charming streets and delicious food
  - Istanbul: Hagia Sophia and Bosphorus cruise
  - Tokyo: Neon lights and sushi
  - Sydney: Opera House and Bondi Beach
- **Future Plans:** Share more stories and photos when catching up with Andrew."""

print(email)
# Out:
# - **Sender:** Daniel
# - **Subject:** My Incredible Journey Around the World!
# - **Trip Highlights:**
#   - New York: Broadway show and skyline
#   - Rio de Janeiro: Copacabana Beach and Christ the Redeemer hike
#   - Cape Town: Natural beauty and safari adventures
#   - Paris: Charming streets and delicious food
#   - Istanbul: Hagia Sophia and Bosphorus cruise
#   - Tokyo: Neon lights and sushi
#   - Sydney: Opera House and Bondi Beach
# - **Future Plans:** Share more stories and photos when catching up with Andrew.

# %%
display(Markdown(email)) # makes nicer to read
# Out:
# - **Sender:** Daniel
# - **Subject:** My Incredible Journey Around the World!
# - **Trip Highlights:**
#   - New York: Broadway show and skyline
#   - Rio de Janeiro: Copacabana Beach and Christ the Redeemer hike
#   - Cape Town: Natural beauty and safari adventures
#   - Paris: Charming streets and delicious food
#   - Istanbul: Hagia Sophia and Bosphorus cruise
#   - Tokyo: Neon lights and sushi
#   - Sydney: Opera House and Bondi Beach
# - **Future Plans:** Share more stories and photos when catching up with Andrew.

# %% [markdown]
# ### directory and folder both are same. Programmers use directory instead of folders

# %% [markdown]
# # Reading journals from food critics
#
#
# * use AI to read large volume of files for us
# * if you have many files of restaurant and famous food and some unrelated files in your system.
# * Use AI to find which files are relevant and which one are irrelevant

# %%
# List of the journal files
files = ["cape_town.txt", "madrid.txt", "rio_de_janeiro.txt", "sydney.txt", "tokyo.txt"]
for file in files:
    # Read journal file for the city
    f = open(file, "r")
    journal = f.read()
    f.close()

    # Create prompt
    prompt = f"""Respond with "Relevant" or "Not relevant": 
    the journal describes restaurants and their specialties. 

    Journal:
    {journal}"""

    # Use LLM to determine if the journal entry is useful
    print(f"{file} -> {get_llm_response(prompt)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 # List of the journal files
#       2 files = ["cape_town.txt", "madrid.txt", "rio_de_janeiro.txt", "sydney.txt", "tokyo.txt"]
#       3 for file in files:
#       4     # Read journal file for the city
# ----> 5     f = open(file, "r")
#       6     journal = f.read()
#       7     f.close()
#       8
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cape_town.txt'

# %% [markdown]
# Output of above cell:
#
#
# cape_town.txt -> Relevant
#
# madrid.txt -> Not relevant
#
# rio_de_janeiro.txt -> Relevant
#
# sydney.txt -> Relevant
#
# tokyo.txt -> Relevant

# %% [markdown]
# # you can ask chatbot to give response in html and then we can read it

# %%
test="""<h2>⏰ Highlighted Schedule</h2>

<h3><b>9:04 – 9:28 AM</b> → 🍽️ Extracting Restaurant Information from Journal</h3>

<h3><b>9:28 – 9:33 AM</b> → ✍️ Review / Practice</h3>

<h3><b>9:33 – 9:41 AM</b> → ☕ Break</h3>

<hr>

<h3><b>9:41 – 10:02 AM</b> → 🧳 Vacation Planning Using CSV</h3>

<h3><b>10:02 – 10:07 AM</b> → ✍️ Notes / Reflection</h3>

<h3><b>10:07 – 10:15 AM</b> → ☕ Break</h3>

<hr>

<h2>💻 Midday Coding Session</h2>

<h3><b>10:15 – 10:39 AM</b> → 🔧 Turning Code Block into Function</h3>

<h3><b>10:39 – 10:44 AM</b> → ✍️ Practice / Cleanup</h3>

<h3><b>10:44 – 10:52 AM</b> → ☕ Break</h3>

<hr>

<h3><b>10:52 – 11:16 AM</b> → 🌍 Creating Detailed Itineration for Cities</h3>

<h3><b>11:16 – 11:21 AM</b> → ✍️ Notes / Review</h3>

<h3><b>11:21 – 11:31 AM</b> → ☕ Longer Break</h3>

<hr>

<h2>🚀 Final Morning Session</h2>

<h3><b>11:31 – 11:51 AM</b> → 📢 Share Your Learning</h3>

<h3><b>11:51 – 11:59 AM</b> → ☕ Break</h3>

<h3><b>11:59 AM – 12:29 PM</b> → 🧠 Quiz</h3>

<h3><b>12:29 – 12:39 PM</b> → 🍽️ Lunch / Relax Break</h3>

<hr>

<h2>🛠️ Deep Work Session</h2>

<h3><b>12:39 – 1:39 PM</b> → 💻 Project Work</h3>

<h3><b>1:39 – 1:44 PM</b> → 📝 Final Notes</h3>"""

# %%
from IPython.display import display, HTML
display(HTML(test))
# Out:
# <h2>⏰ Highlighted Schedule</h2>
#
# <h3><b>9:04 – 9:28 AM</b> → 🍽️ Extracting Restaurant Information from Journal</h3>
#
# <h3><b>9:28 – 9:33 AM</b> → ✍️ Review / Practice</h3>
#
# <h3><b>9:33 – 9:41 AM</b> → ☕ Break</h3>
#
# <hr>
#
# <h3><b>9:41 – 10:02 AM</b> → 🧳 Vacation Planning Using CSV</h3>
#
# <h3><b>10:02 – 10:07 AM</b> → ✍️ Notes / Reflection</h3>
#
# <h3><b>10:07 – 10:15 AM</b> → ☕ Break</h3>
#
# <hr>
#
# <h2>💻 Midday Coding Session</h2>
#
# <h3><b>10:15 – 10:39 AM</b> → 🔧 Turning Code Block into Function</h3>
#
# <h3><b>10:39 – 10:44 AM</b> → ✍️ Practice / Cleanup</h3>
#
# <h3><b>10:44 – 10:52 AM</b> → ☕ Break</h3>
#
# <hr>
#
# <h3><b>10:52 – 11:16 AM</b> → 🌍 Creating Detailed Itineration for Cities</h3>
#
# <h3><b>11:16 – 11:21 AM</b> → ✍️ Notes / Review</h3>
#
# <h3><b>11:21 – 11:31 AM</b> → ☕ Longer Break</h3>
#
# <hr>
#
# <h2>🚀 Final Morning Session</h2>
#
# <h3><b>11:31 – 11:51 AM</b> → 📢 Share Your Learning</h3>
#
# <h3><b>11:51 – 11:59 AM</b> → ☕ Break</h3>
#
# ...

# %% [markdown]
# # Get response in CSV format (comma seperated value)

# %% [markdown]
# output will be like this
#
# Restaurant,Dish
#
# Confeitaria Colombo,pastel de nata
#
# Fogo de Chão,picanha
#
# Olympe,moqueca de caju
#
# Aprazível,galinhada

# %%
files = ["cape_town.txt", "istanbul.txt", "new_york.txt", "paris.txt", 
          "rio_de_janeiro.txt", "sydney.txt", "tokyo.txt"]

for file in files:
    #Open file and read contents
    journal_entry = read_journal(file)

    #Extract restaurants and display csv
    prompt =  f"""Please extract a comprehensive list of the restaurants 
    and their respective best dishes mentioned in the following journal entry. 
    
    Ensure that each restaurant name is accurately identified and listed. 
    Provide your answer in CSV format, ready to save.

    Exclude the "```csv" declaration, don't add spaces after the 
    comma, include column headers.

    Format:
    Restaurant, Dish
    Res_1, Dsh_1
    ...

    Journal entry:
    {journal_entry}
    """
    
    print(file)
    print_llm_response(prompt)
    print("") # Prints a blank line!

# %%
# How to save the file 
f = open("test.html", "w", encoding="utf-8") 
f.write(test) 
f.close()

# %% [markdown]
# # Working with CSV file

# %% [raw]
# CSV file:
# Arrival,Departure,City,Country
# July-01,July-08,New York,USA
# July-09,July-16,Rio de Janeiro,Brazil
# July-17,July-24,Cape Town,South Africa
# July-25,August-01,Istanbul,Turkey
# August-02,August-09,Paris,France
# August-10,August-17,Tokyo,Japan
# August-18,August-25,Sydney,Australia

# %% [raw]
# 1. Table is a structured data and text are unstructured data

# %%
import csv
f=open("trip.csv","r")
csv_reader=csv.DictReader(f) #reads each row of the CSV as a dictionary.
iternary=[]
for items in csv_reader:
    print(items)
    iternary.append(items)
print(iternary)
# Out:
# {'Arrival': 'July-01', 'Departure': 'July-08', 'City': 'New York', 'Country': 'USA'}
# {'Arrival': 'July-09', 'Departure': 'July-16', 'City': 'Rio de Janeiro', 'Country': 'Brazil'}
# {'Arrival': 'July-17', 'Departure': 'July-24', 'City': 'Cape Town', 'Country': 'South Africa'}
# {'Arrival': 'July-25', 'Departure': 'August-01', 'City': 'Istanbul', 'Country': 'Turkey'}
# {'Arrival': 'August-02', 'Departure': 'August-09', 'City': 'Paris', 'Country': 'France'}
# {'Arrival': 'August-10', 'Departure': 'August-17', 'City': 'Tokyo', 'Country': 'Japan'}
# {'Arrival': 'August-18', 'Departure': 'August-25', 'City': 'Sydney', 'Country': 'Australia'}
# ...

# %%
# how to access each element
print(iternary[0]["Country"])
trip_stop=iternary[0]
trip_stop["City"]
# Out:
# USA
# 'New York'

# %%
# filtering by country

filtered_data=[]
for trip_stop in iternary:
    if trip_stop["Country"]=='Australia':
        filtered_data.append(trip_stop)
print(filtered_data)
# Out:
# [{'Arrival': 'August-18', 'Departure': 'August-25', 'City': 'Sydney', 'Country': 'Australia'}]

# %% [markdown]
# # Function
#
#
# * reuse code instead of writting same code again

# %%
# defining function without return
def open_file(file): # file is parameter
    f=open(file,'r')
    input=f.read()
    print(input)
open_file("trip.csv")
# Out:
# Arrival,Departure,City,Country
# July-01,July-08,New York,USA
# July-09,July-16,Rio de Janeiro,Brazil
# July-17,July-24,Cape Town,South Africa
# July-25,August-01,Istanbul,Turkey
# August-02,August-09,Paris,France
# August-10,August-17,Tokyo,Japan
# August-18,August-25,Sydney,Australia

# %%
# defining function with return
def open_file(file):
    f=open(file,'r')
    input=f.read()
    return input
print_file=open_file("trip.csv")
print(print_file)
# Out:
# Arrival,Departure,City,Country
# July-01,July-08,New York,USA
# July-09,July-16,Rio de Janeiro,Brazil
# July-17,July-24,Cape Town,South Africa
# July-25,August-01,Istanbul,Turkey
# August-02,August-09,Paris,France
# August-10,August-17,Tokyo,Japan
# August-18,August-25,Sydney,Australia

# %% [markdown]
# ### w mode will create new file if it does not exist or if file already there, then it will remove all the previous content and overwrite with new content

# %% [markdown]
# # Packages and API
#
#
# * We can use code written by other using import statement
# * use other code and build on top of it
# * An API (Application Programming Interface) is a way for two software programs to communicate with each other.

# %% [raw]
# Example 1:
# Your Python program asks:
# What is the weather in Gainesville?
#
# The Weather API returns:
# Sunny, 85°F
#
# Example 2: ChatGPT API
# Your Python program sends:
# "Explain machine learning in simple terms"
#
# The ChatGPT API returns:
# "Machine learning is a way for computers to learn patterns from data..."

# %% [markdown]
# ### from python_file_name.py import function_name
# * give python file name where this function is defined
# * from helper_function import celsius_to_fahrenheit
#
# ### Differnt way to use import function
# * import python file name --> will import all the functions in that file
# * to use the function
# * import helper_function
# * helper_function.print_llm_response
#
# * from helper_functon import get_llm_resoonse
# * this is recommended to import function which we will use , use function without mentioning the py file name
# * from helper_function import *
# * this will import all the function so this is not recommented and even for this we dont need to use py file name to access the function

# %% [markdown]
# # Python Built-in packages like math/statistics/random packages
# * package is like a collection of functions for a specific set of task like maths or statistics

# %%
from math import cos, sin, pi
print(pi)
values = [0, pi/2, pi, 3/2*pi, 2*pi]
for value in values:
    print(f"The cosine of {value:.2f} is {cos(value):.2f}")
# Out:
# 3.141592653589793
# The cosine of 0.00 is 1.00
# The cosine of 1.57 is 0.00
# The cosine of 3.14 is -1.00
# The cosine of 4.71 is -0.00
# The cosine of 6.28 is 1.00

# %%
from statistics import mean, stdev
my_friends_heights = [160, 172, 155, 180, 165, 170, 158, 182, 175, 168]
print(mean(my_friends_heights))
print(stdev(my_friends_heights))
# Out:
# 168.5
# 9.119576013536301

# %%
from random import sample
spices = ["cumin", "turmeric", "oregano", "paprika"]
vegetables = ["lettuce", "tomato", "carrot", "broccoli"]
proteins = ["chicken", "tofu", "beef", "fish", "tempeh"]
random_spices = sample(spices, 2)
random_vegetables = sample(vegetables, 2)
random_protein = sample(proteins, 1)
print(random_protein)
print(random_spices)
print(random_vegetables)
# Out:
# ['fish']
# ['cumin', 'paprika']
# ['broccoli', 'lettuce']

# %% [markdown]
# # Third party packages
# * written by other people and shared with public which we can use
# * Examples are Pandas and Matplotlib

# %%
# install the package beautiful soup version 4
# used for interpreting HTML web pages
# !pip install bs4
# Out:
# ...
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# after installing the package, we can import functions in that
from bs4 import BeautifulSoup
import requests
from IPython.display import HTML, display


# The url from one of the Batch's newsletter
url = 'https://www.deeplearning.ai/the-batch/the-world-needs-more-intelligence/'

# Getting the content from the webpage's contents
response = requests.get(url)

# Print the response from the requests
print(response)

HTML(f'<iframe src={url} width="60%" height="400"></iframe>')
# Out:
# <Response [200]>
# C:\Users\lekal\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\display.py:447: UserWarning: Consider using IPython.display.IFrame instead
#   warnings.warn("Consider using IPython.display.IFrame instead")
# <iframe src=https://www.deeplearning.ai/the-batch/the-world-needs-more-intelligence/ width="60%" height="400"></iframe>

# %%
# this web page has images, ad and other things,
# we using beautiful soup to extract text 
# Using beautifulsoup to extract the text
soup = BeautifulSoup(response.text, 'html.parser')
# Find all the text in paragraph elements on the webpage
all_text = soup.find_all('p')

# Create an empty string to store the extracted text
combined_text = ""

# Iterate over 'all_text' and add to the combined_text string
for text in all_text:
    combined_text = combined_text + "\n" + text.get_text()

# Print the final combined text
print(combined_text)
# Out:
# ✨ New Course! Enroll in AI Agents for Image and Video Generation
# Dear friends,
# Last year, a number of large businesses and individuals went to the media and governments and pushed the message that AI is scary, impossible to control, and might even lead to human extinction. Unfortunately they succeeded: Now many people think AI is scary. But when I speak with regulators, media, and private citizens, I like to bring the issue of whether AI is beneficial or harmful back to a very basic question: Are we better off with more, or less, intelligence in the world?
# ...

# %% [markdown]
# ### use OpenAI API to get the summary of this text message

# %% [markdown]
# # API : Application program interface let you ask another computer to give you data or carry out a service

# %%
import os
import requests
from dotenv import load_dotenv

# %%
load_dotenv('.env', override=True)
api_key = os.getenv('WEATHER_API_KEY')
# Store the latitude value in the 'lat' variable
lat = 37.4419   # Palo Alto, CA

# Store the longitude value in the 'long' variable
lon = -122.1430
url = f"https://api.openweathermap.org/data/2.5/forecast?units=metric&cnt=1&lat={lat}&lon={lon}&appid={api_key}"

# Use the get function from the requests library to store the response from the API
response = requests.get(url)
# Take the response from the API (in JSON) and assign it to a Python dictionary
data = response.json()

# Print
print(data)
# Out:
# {'cod': 401, 'message': 'Invalid API key. Please see https://openweathermap.org/faq#error401 for more info.'}

# %% [raw]
# This will be the output
# {'cod': '200', 'message': 0, 'cnt': 1, 'list': [{'dt': 1780088400, 'main': {'temp': 18.14, 'feels_like': 17.76, 'temp_min': 18.14, 'temp_max': 19.8, 'pressure': 1017, 'sea_level': 1017, 'grnd_level': 1003, 'humidity': 67, 'temp_kf': -1.66}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'clouds': {'all': 79}, 'wind': {'speed': 3.73, 'deg': 288, 'gust': 3.45}, 'visibility': 10000, 'pop': 0, 'sys': {'pod': 'd'}, 'dt_txt': '2026-05-29 21:00:00'}], 'city': {'id': 5380748, 'name': 'Palo Alto', 'coord': {'lat': 37.4419, 'lon': -122.143}, 'country': 'US', 'population': 64403, 'timezone': -25200, 'sunrise': 1780059037, 'sunset': 1780111304}}

# %% [markdown]
# ### now use openai API to get what kind of dress recommendation for the given temperature
#
# * don't put your API key in code cell rather use env file as someone access to your code can view your API Key
